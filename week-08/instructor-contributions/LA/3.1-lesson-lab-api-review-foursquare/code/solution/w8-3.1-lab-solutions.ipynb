# %% [markdown]
# # Setting up Foursquare data for analysis

# %% [markdown]
# > Note: This will be a very open ended lab, since everyone may end up using different geographies and starting seed geographies. Be prepared to walk around and hand-hold some people, I've tested this out on several locales around me and it works, for most, but if you don't have a good starting seed location, the procedure may not scrape well.
#
# Today's lab is going to get your hands dirty with respect to the Foursquare API. We're also going to build a simple crawler/scraper that will go through the JSON hierarchy, extract the data we want, and deposit them into a Pandas table so we can do simple analysis.
#
# Just in case you're unfamiliar with this concept, please refer to the Wikipedia page (it's actually pretty good): https://en.wikipedia.org/wiki/Web_scraping, and maybe spend a few moments discussing the concepts and how it could help you in the future as a data scientist to have this "hackish" skill.

# %% [markdown]
# Setup your access token to foursquare

# %%
# Solutions

import foursquare
import json
import pandas as pd
import unicodedata
import user_keys 

CLIENT_ID = user_keys.CLIENT_ID   # Input your client id/ client secret here
CLIENT_SECRET = user_keys.CLIENT_SECRET

client = foursquare.Foursquare(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)

# %% [markdown]
# Get parameters for a bounded box here: http://boundingbox.klokantech.com/
# Output CSV and copy and paste values here

# %%
#Here are values for Santa Monica with bounding box
x = -118.517415
y = 33.993166
z = -118.443426
t = 34.05056

bounding_box = [x,y,z,t]  #Input the raw CSV form in here

# %%
#review structure of json via the readme and api docs
GA_LAT = 34.0108014
GA_LONG = -118.5184891
data = client.venues.search(params={'ll': "34.0108014, -118.5184891"})  # Put in a lat/long you're interested in

print 'Output venue name:', data['venues'][0]['name']
print 'Number of venues: ', len(data['venues'])
# Out:
# Output venue name: Downtown Santa Monica
# Number of venues:  30

# %% [markdown]
# Use a foursquare python library method to search for suitable venues around a city near you. Print the associated JSON output in a nice way with appropriate spacing and indentation

# %%
# Solution

starting_list = client.venues.search(params={'near': 'Santa Monica, CA', 'radius':'1500'})
print(starting_list)
# Out:
# {'confident': False, 'geocode': {'parents': [], 'what': u'', 'where': 'santa monica ca', 'feature': {'highlightedName': '<b>Santa Monica</b>, <b>CA</b>, United States', 'displayName': 'Santa Monica, CA, United States', 'name': 'Santa Monica', 'longId': '72057594043321148', 'cc': 'US', 'id': 'geonameid:5393212', 'geometry': {'center': {'lat': 34.01945, 'lng': -118.49119}, 'bounds': {'sw': {'lat': 33.995416, 'lng': -118.517415}, 'ne': {'lat': 34.05056, 'lng': -118.443517}}}, 'matchedName': 'Santa Monica, CA, United States', 'woeType': 7, 'slug': 'santa-monica-california'}}, 'venues': [{'hasMenu': True, 'verified': True, 'name': 'Jack in the Box', 'referralId': 'v-1469606406', 'venueChains': [{'id': '556e1846a7c82e6b72513d66'}], 'url': 'http://https://www.jackinthebox.com/locations/153', 'menu': {'url': 'https://foursquare.com/v/jack-in-the-box/4b004cebf964a520813c22e3/menu', 'mobileUrl': 'https://foursquare.com/v/4b004cebf964a520813c22e3/device_menu', 'type': 'Menu', 'anchor': 'View Menu', 'label': 'Menu'}, 'storeId': '153', 'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'}, 'specials': {'count': 0, 'items': []}, 'allowMenuUrlEdit': True, 'contact': {'phone': '3104583584', 'twitter': 'jackinthebox', 'formattedPhone': '(310) 458-3584'}, 'hasPerk': False, 'location': {'city': 'Santa Monica', 'cc': 'US', 'country': 'United States', 'postalCode': '90401', 'state': 'CA', 'formattedAddress': ['802 Santa Monica Blvd (Lincoln)', 'Santa Monica, CA 90401', 'United States'], 'crossStreet': 'Lincoln', 'address': '802 Santa Monica Blvd', 'lat': 34.01979897799737, 'lng': -118.49132537841797}, 'stats': {'tipCount': 12, 'checkinsCount': 1585, 'usersCount': 879}, 'id': '4b004cebf964a520813c22e3', 'categories': [{'pluralName': 'Burger Joints', 'primary': True, 'name': 'Burger Joint', 'shortName': 'Burgers', 'id': '4bf58dd8d48988d16c941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_', 'suffix': '.png'}}]}, {'verified': False, 'name': 'City of Santa Monica', 'referralId': 'v-1469606406', 'url': 'http://www.santamonica.com', 'hereNow': {'count': 1, 'groups': [{'count': 1, 'items': [], 'type': 'others', 'name': 'Other people here'}], 'summary': 'One other person is here'}, 'specials': {'count': 0, 'items': []}, 'venueChains': [], 'contact': {}, 'hasPerk': False, 'location': {'cc': 'US', 'country': 'United States', 'postalCode': '90401', 'state': 'California', 'formattedAddress': ['CA 90401', 'United States'], 'lat': 34.0182338774957, 'lng': -118.4896945953369}, 'stats': {'tipCount': 87, 'checkinsCount': 47372, 'usersCount': 16862}, 'id': '4c47c5d976d72d7f2a673e4d', 'categories': [{'pluralName': 'Cities', 'primary': True, 'name': 'City', 'shortName': 'City', 'id': '50aa9e094b90af0d42d5de0d', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_', 'suffix': '.png'}}]}, {'verified': False, 'name': 'Ponte Almeja', 'referralId': 'v-1469606406', 'venueChains': [], 'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'}, 'specials': {'count': 0, 'items': []}, 'allowMenuUrlEdit': True, 'contact': {}, 'hasPerk': False, 'location': {'city': 'Santa Monica', 'cc': 'US', 'country': 'United States', 'postalCode': '90401', 'state': 'CA', 'formattedAddress': [u'Santa M\xf3nica', 'Santa Monica, CA 90401', 'United States'], 'address': u'Santa M\xf3nica', 'lat': 34.019454, 'lng': -118.491191}, 'stats': {'tipCount': 0, 'checkinsCount': 16, 'usersCount': 11}, 'id': '4f00b4ce93adc82459849812', 'categories': [{'pluralName': 'Seafood Restaurants', 'primary': True, 'name': 'Seafood Restaurant', 'shortName': 'Seafood', 'id': '4bf58dd8d48988d1ce941735', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_', 'suffix': '.png'}}]}, {'verified': False, 'name': 'Metro 704 Santa Monica and Lincoln', 'referralId': 'v-1469606406', 'venueChains': [], 'hereNow': {'count': 0, 'groups': [], 'summary': 'Nobody here'}, 'specials': {'count': 0, 'items': []}, 'contact': {}, 'hasPerk': Fal ...

# %% [markdown]
# Wow... that should look like a total mess to you. Read the following docs: https://docs.python.org/2/library/json.html, and read the part about pretty printing. Once you think you've understood the method, deploy it here and see the world a difference a bit of spacing and indenting makes!

# %%
print(json.dumps(starting_list, indent = 4))
# Out:
# {
#     "confident": false,
#     "geocode": {
#         "parents": [],
#         "what": "",
#         "where": "santa monica ca",
#         "feature": {
#             "highlightedName": "<b>Santa Monica</b>, <b>CA</b>, United States",
#             "displayName": "Santa Monica, CA, United States",
#             "name": "Santa Monica",
#             "longId": "72057594043321148",
#             "cc": "US",
#             "id": "geonameid:5393212",
#             "geometry": {
#                 "center": {
#                     "lat": 34.01945,
#                     "lng": -118.49119
#                 },
#                 "bounds": {
#                     "sw": {
#                         "lat": 33.995416,
#                         "lng": -118.517415
#                     },
#                     "ne": {
#                         "lat": 34.05056,
#                         "lng": -118.443517
#                     }
#                 }
#             },
#             "matchedName": "Santa Monica, CA, United States",
#             "woeType": 7,
#             "slug": "santa-monica-california"
#         }
#     },
#     "venues": [
#         {
#             "hasMenu": true,
#             "verified": true,
#             "name": "Jack in the Box",
#             "referralId": "v-1469606406",
#             "venueChains": [
#                 {
#                     "id": "556e1846a7c82e6b72513d66"
#                 }
#             ],
#             "url": "http://https://www.jackinthebox.com/locations/153",
#             "menu": {
#                 "url": "https://foursquare.com/v/jack-in-the-box/4b004cebf964a520813c22e3/menu",
#                 "mobileUrl": "https://foursquare.com/v/4b004cebf964a520813c22e3/device_menu",
#                 "type": "Menu",
#                 "anchor": "View Menu",
#                 "label": "Menu"
#             },
#             "storeId": "153",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3104583584",
#                 "twitter": "jackinthebox",
#                 "formattedPhone": "(310) 458-3584"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "802 Santa Monica Blvd (Lincoln)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Lincoln",
#                 "address": "802 Santa Monica Blvd",
#                 "lat": 34.01979897799737,
#                 "lng": -118.49132537841797
#             },
#             "stats": {
#                 "tipCount": 12,
#                 "checkinsCount": 1585,
#                 "usersCount": 879
#             },
#             "id": "4b004cebf964a520813c22e3",
#             "categories": [
#                 {
#                     "pluralName": "Burger Joints",
#                     "primary": true,
#                     "name": "Burger Joint",
#                     "shortName": "Burgers",
#                     "id": "4bf58dd8d48988d16c941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/burger_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "City of Santa Monica",
#             "referralId": "v-1469606406",
#             "url": "http://www.santamonica.com",
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [],
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "California",
#                 "formattedAddress": [
#                     "CA 90401",
#                     "United States"
#                 ],
#                 "lat": 34.0182338774957,
#                 "lng": -118.4896945953369
#             },
#             "stats": {
#                 "tipCount": 87,
#                 "checkinsCount": 47372,
#                 "usersCount": 16862
#             },
#             "id": "4c47c5d976d72d7f2a673e4d",
#             "categories": [
#                 {
#                     "pluralName": "Cities",
#                     "primary": true,
#                     "name": "City",
#                     "shortName": "City",
#                     "id": "50aa9e094b90af0d42d5de0d",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Ponte Almeja",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "Santa M\u00f3nica",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "Santa M\u00f3nica",
#                 "lat": 34.019454,
#                 "lng": -118.491191
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 16,
#                 "usersCount": 11
#             },
#             "id": "4f00b4ce93adc82459849812",
#             "categories": [
#                 {
#                     "pluralName": "Seafood Restaurants",
#                     "primary": true,
#                     "name": "Seafood Restaurant",
#                     "shortName": "Seafood",
#                     "id": "4bf58dd8d48988d1ce941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/seafood_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Metro 704 Santa Monica and Lincoln",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "Santa Monica, CA",
#                     "United States"
#                 ],
#                 "lat": 34.01944327587188,
#                 "lng": -118.49141120910645
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 31,
#                 "usersCount": 24
#             },
#             "id": "4e8a1a0c775bfc10fd281a6b",
#             "categories": [
#                 {
#                     "pluralName": "Bus Stations",
#                     "primary": true,
#                     "name": "Bus Station",
#                     "shortName": "Bus Station",
#                     "id": "4bf58dd8d48988d1fe931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/busstation_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Solidarity at Warszawa",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1414 Lincoln Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "1414 Lincoln Blvd",
#                 "lat": 34.019092931947654,
#                 "lng": -118.49104654732324
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 60,
#                 "usersCount": 56
#             },
#             "id": "56a3311c498e29423a35d2dc",
#             "categories": [
#                 {
#                     "pluralName": "Cocktail Bars",
#                     "primary": true,
#                     "name": "Cocktail Bar",
#                     "shortName": "Cocktail",
#                     "id": "4bf58dd8d48988d11e941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Santa Monica State Beach",
#             "referralId": "v-1469606406",
#             "url": "http://www.smgov.net/portals/beach/",
#             "storeId": "",
#             "hereNow": {
#                 "count": 1,
#                 "groups": [
#                     {
#                         "count": 1,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "One other person is here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [
#                 {
#                     "id": "556a4e08a7c8957d73d6ce54"
#                 }
#             ],
#             "contact": {
#                 "phone": "8188800363",
#                 "formattedPhone": "(818) 880-0363"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90402",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1432 Palisades Beach Rd (at Colorado Ave.)",
#                     "Santa Monica, CA 90402",
#                     "United States"
#                 ],
#                 "crossStreet": "at Colorado Ave.",
#                 "address": "1432 Palisades Beach Rd",
#                 "lat": 34.01122614187616,
#                 "lng": -118.499436378479
#             },
#             "stats": {
#                 "tipCount": 240,
#                 "checkinsCount": 64239,
#                 "usersCount": 42551
#             },
#             "id": "49e27207f964a52016621fe3",
#             "categories": [
#                 {
#                     "pluralName": "Beaches",
#                     "primary": true,
#                     "name": "Beach",
#                     "shortName": "Beach",
#                     "id": "4bf58dd8d48988d1e2941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/beach_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Truetone Music",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "url": "http://www.truetonemusic.com",
#             "storeId": "",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3103938232",
#                 "twitter": "truetonemusic",
#                 "formattedPhone": "(310) 393-8232"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "714 Santa Monica Blvd (Lincoln Blvd.)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Lincoln Blvd.",
#                 "address": "714 Santa Monica Blvd",
#                 "lat": 34.018947513547964,
#                 "lng": -118.49185645580292
#             },
#             "venuePage": {
#                 "id": "43294885"
#             },
#             "stats": {
#                 "tipCount": 6,
#                 "checkinsCount": 380,
#                 "usersCount": 265
#             },
#             "id": "4a984658f964a520472b20e3",
#             "categories": [
#                 {
#                     "pluralName": "Music Stores",
#                     "primary": true,
#                     "name": "Music Store",
#                     "shortName": "Music Store",
#                     "id": "4bf58dd8d48988d1fe941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/music_instruments_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "CVS Pharmacy",
#             "referralId": "v-1469606406",
#             "venueChains": [
#                 {
#                     "id": "556f5631bd6a75a99036ab9b"
#                 }
#             ],
#             "url": "http://cvs.com/extracare",
#             "storeId": "CVS 9726",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3103191318",
#                 "twitter": "cvs_extra",
#                 "formattedPhone": "(310) 319-1318"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1411 Lincoln Blvd (at Santa Monica Blvd)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "at Santa Monica Blvd",
#                 "address": "1411 Lincoln Blvd",
#                 "lat": 34.01923263029678,
#                 "lng": -118.49070441190071
#             },
#             "stats": {
#                 "tipCount": 10,
#                 "checkinsCount": 2023,
#                 "usersCount": 757
#             },
#             "id": "4b4d218ff964a5200dcc26e3",
#             "categories": [
#                 {
#                     "pluralName": "Pharmacies",
#                     "primary": true,
#                     "name": "Pharmacy",
#                     "shortName": "Pharmacy",
#                     "id": "4bf58dd8d48988d10f951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Centinela Feed & Pet Supplies",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3104517140",
#                 "formattedPhone": "(310) 451-7140"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1448 Lincoln Blvd (at Broadway)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "at Broadway",
#                 "address": "1448 Lincoln Blvd",
#                 "lat": 34.01830501905362,
#                 "lng": -118.4905207157135
#             },
#             "stats": {
#                 "tipCount": 7,
#                 "checkinsCount": 619,
#                 "usersCount": 273
#             },
#             "id": "49c73122f964a520a1571fe3",
#             "categories": [
#                 {
#                     "pluralName": "Pet Stores",
#                     "primary": true,
#                     "name": "Pet Store",
#                     "shortName": "Pet Store",
#                     "id": "4bf58dd8d48988d100951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/pet_store_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Toyota Santa Monica",
#             "referralId": "v-1469606406",
#             "venueChains": [
#                 {
#                     "id": "556f3d35bd6a007c7737e5cc"
#                 },
#                 {
#                     "id": "561ff01b498e8b23a9c5b4f9"
#                 },
#                 {
#                     "id": "568c4f8e498ec8e3dff565dd"
#                 }
#             ],
#             "url": "http://bradleyb@b-sides.org",
#             "storeId": "",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "facebookName": "Toyota Santa Monica",
#                 "twitter": "lacarguy",
#                 "phone": "4243369177",
#                 "facebook": "102792619510",
#                 "formattedPhone": "(424) 336-9177",
#                 "facebookUsername": "toyotasantamonica"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "801 Santa Monica Blvd (at Lincoln Blvd)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "at Lincoln Blvd",
#                 "address": "801 Santa Monica Blvd",
#                 "lat": 34.0200324209371,
#                 "lng": -118.49162817591613
#             },
#             "stats": {
#                 "tipCount": 16,
#                 "checkinsCount": 1212,
#                 "usersCount": 664
#             },
#             "id": "4b72e8d8f964a520f38e2de3",
#             "categories": [
#                 {
#                     "pluralName": "Auto Dealerships",
#                     "primary": true,
#                     "name": "Auto Dealership",
#                     "shortName": "Auto Dealer",
#                     "id": "4eb1c1623b7b52c0e1adc2ec",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/automotive_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Swimming pool",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "Santa monica",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "Santa monica",
#                 "lat": 34.01945572234617,
#                 "lng": -118.4902881461816
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 12,
#                 "usersCount": 9
#             },
#             "id": "4fe04b63e4b0872cf24006cb",
#             "categories": [
#                 {
#                     "pluralName": "Pools",
#                     "primary": true,
#                     "name": "Pool",
#                     "shortName": "Pool",
#                     "id": "4bf58dd8d48988d15e941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/pool_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Way Over Yonder Festival- Santa Monica Pier",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "Santa Monica, CA",
#                     "United States"
#                 ],
#                 "lat": 34.0194543,
#                 "lng": -118.4911912
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "538a89db11d2ac444a2900b1",
#             "categories": []
#         },
#         {
#             "verified": false,
#             "name": "Young World/Interscope Records",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "twitter": "ywmusicgroup"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90404",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "2220 Colorado Ave",
#                     "Santa Monica, CA 90404",
#                     "United States"
#                 ],
#                 "address": "2220 Colorado Ave",
#                 "lat": 34.01945,
#                 "lng": -118.49119
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 3
#             },
#             "id": "53cea24c498eae88f39ee43e",
#             "categories": [
#                 {
#                     "pluralName": "Music Schools",
#                     "primary": true,
#                     "name": "Music School",
#                     "shortName": "Music School",
#                     "id": "4f04b10d2fb6e1c99f3db0be",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/school_music_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Orci Sight seeing Party Bus",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "lat": 34.019348059234645,
#                 "lng": -118.49108076082655
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4fe2659de4b0a812e9aebc41",
#             "categories": [
#                 {
#                     "pluralName": "General Travel",
#                     "primary": true,
#                     "name": "General Travel",
#                     "shortName": "Travel",
#                     "id": "4bf58dd8d48988d1f6931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Mobil",
#             "referralId": "v-1469606406",
#             "venueChains": [
#                 {
#                     "id": "5591f502498e0605d742144d"
#                 }
#             ],
#             "url": "http://exxon.com",
#             "storeId": "306027",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3104512355",
#                 "formattedPhone": "(310) 451-2355"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "731 Santa Monica Blvd (at Lincoln)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "at Lincoln",
#                 "address": "731 Santa Monica Blvd",
#                 "lat": 34.019482219308266,
#                 "lng": -118.49173081604357
#             },
#             "stats": {
#                 "tipCount": 3,
#                 "checkinsCount": 364,
#                 "usersCount": 226
#             },
#             "id": "4b453fddf964a5200c0926e3",
#             "categories": [
#                 {
#                     "pluralName": "Gas Stations",
#                     "primary": true,
#                     "name": "Gas Station",
#                     "shortName": "Gas Station",
#                     "id": "4bf58dd8d48988d113951735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gas_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Celliant",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90404",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1617 Broadway",
#                     "Santa Monica, CA 90404",
#                     "United States"
#                 ],
#                 "address": "1617 Broadway",
#                 "lat": 34.019626327600555,
#                 "lng": -118.49120621027807
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 3
#             },
#             "id": "4e52a88cd22d41fba7a48112",
#             "categories": []
#         },
#         {
#             "verified": true,
#             "name": "Third Street Promenade",
#             "referralId": "v-1469606406",
#             "url": "http://www.downtownsm.com/",
#             "storeId": "",
#             "hereNow": {
#                 "count": 6,
#                 "groups": [
#                     {
#                         "count": 6,
#                         "items": [],
#                         "type": "others",
#                         "name": "Other people here"
#                     }
#                 ],
#                 "summary": "6 people are here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [
#                 {
#                     "id": "5568e044a7c8a9cf8ec35df7"
#                 }
#             ],
#             "contact": {
#                 "facebookName": "Downtown Santa Monica",
#                 "twitter": "dtsantamonica",
#                 "phone": "3103938355",
#                 "facebook": "288122994848",
#                 "formattedPhone": "(310) 393-8355",
#                 "facebookUsername": "DowntownSantaMonica"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "3rd St. (btwn Wilshire & Broadway)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "btwn Wilshire & Broadway",
#                 "address": "3rd St.",
#                 "lat": 34.01608181718752,
#                 "lng": -118.49674344062805
#             },
#             "stats": {
#                 "tipCount": 229,
#                 "checkinsCount": 122689,
#                 "usersCount": 46467
#             },
#             "id": "44ded2f5f964a520d2361fe3",
#             "categories": [
#                 {
#                     "pluralName": "Shopping Malls",
#                     "primary": true,
#                     "name": "Shopping Mall",
#                     "shortName": "Mall",
#                     "id": "4bf58dd8d48988d1fd941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/mall_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Carpet Showcase",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1436 Lincoln Blvd (Santa Monica Blvd)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Santa Monica Blvd",
#                 "address": "1436 Lincoln Blvd",
#                 "lat": 34.01927412189014,
#                 "lng": -118.49139438427677
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 1,
#                 "usersCount": 1
#             },
#             "id": "4fd790ffe4b0b5d989c9535d",
#             "categories": [
#                 {
#                     "pluralName": "Miscellaneous Shops",
#                     "primary": true,
#                     "name": "Miscellaneous Shop",
#                     "shortName": "Shop",
#                     "id": "4bf58dd8d48988d1ff941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Hi De Ho Comics & Books",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "url": "http://www.hidehocomics.com",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3103942820",
#                 "facebook": "257068915114",
#                 "formattedPhone": "(310) 394-2820",
#                 "facebookName": "Hi De Ho Comics & Books with Pictures"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1431 Lincoln Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "1431 Lincoln Blvd",
#                 "lat": 34.018941209996775,
#                 "lng": -118.49047061895465
#             },
#             "stats": {
#                 "tipCount": 13,
#                 "checkinsCount": 1785,
#                 "usersCount": 502
#             },
#             "id": "4aa836d0f964a520245020e3",
#             "categories": [
#                 {
#                     "pluralName": "Comic Shops",
#                     "primary": true,
#                     "name": "Comic Shop",
#                     "shortName": "Comic Shop",
#                     "id": "52f2ab2ebcbc57f1066b8b18",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/comic_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "hasMenu": true,
#             "verified": false,
#             "name": "Warszawa",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "url": "http://warszawarestaurant.com",
#             "menu": {
#                 "url": "https://foursquare.com/v/warszawa/4549b820f964a520953c1fe3/menu",
#                 "mobileUrl": "https://foursquare.com/v/4549b820f964a520953c1fe3/device_menu",
#                 "type": "Menu",
#                 "anchor": "View Menu",
#                 "label": "Menu"
#             },
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3103938831",
#                 "formattedPhone": "(310) 393-8831"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1414 Lincoln Blvd (at Santa Monica Blvd.)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "at Santa Monica Blvd.",
#                 "address": "1414 Lincoln Blvd",
#                 "lat": 34.018921,
#                 "lng": -118.491311
#             },
#             "stats": {
#                 "tipCount": 22,
#                 "checkinsCount": 2861,
#                 "usersCount": 1530
#             },
#             "id": "4549b820f964a520953c1fe3",
#             "categories": [
#                 {
#                     "pluralName": "Eastern European Restaurants",
#                     "primary": true,
#                     "name": "Eastern European Restaurant",
#                     "shortName": "Eastern European",
#                     "id": "4bf58dd8d48988d109941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/default_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Santa Monica and Lincoln Bus Stop",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "California",
#                 "formattedAddress": [
#                     "California",
#                     "United States"
#                 ],
#                 "lat": 34.019327,
#                 "lng": -118.491516
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 115,
#                 "usersCount": 38
#             },
#             "id": "4f6a27f1e4b059d243617a20",
#             "categories": [
#                 {
#                     "pluralName": "Bus Stations",
#                     "primary": true,
#                     "name": "Bus Station",
#                     "shortName": "Bus Station",
#                     "id": "4bf58dd8d48988d1fe931735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/travel/busstation_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Kumon of Santa Monica",
#             "referralId": "v-1469606406",
#             "url": "http://www.kumon.com/SANTA-MONICA",
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "venueChains": [
#                 {
#                     "id": "556e119fa7c82e6b725012e8"
#                 }
#             ],
#             "contact": {
#                 "phone": "3103940902",
#                 "formattedPhone": "(310) 394-0902"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "718 Santa Monica Blvd (btwn 7th & Lincoln)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "btwn 7th & Lincoln",
#                 "address": "718 Santa Monica Blvd",
#                 "lat": 34.01932,
#                 "lng": -118.49166
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 18,
#                 "usersCount": 5
#             },
#             "id": "4da084783edff04d70974299",
#             "categories": [
#                 {
#                     "pluralName": "Schools",
#                     "primary": true,
#                     "name": "School",
#                     "shortName": "School",
#                     "id": "4bf58dd8d48988d13b941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/school_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "As Seen On TV Section",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "CVS Pharmacy",
#                     "Santa Monica, CA",
#                     "United States"
#                 ],
#                 "address": "CVS Pharmacy",
#                 "lat": 34.019287,
#                 "lng": -118.490714
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 3,
#                 "usersCount": 1
#             },
#             "id": "51a6c73c498eeedebbf3d938",
#             "categories": [
#                 {
#                     "pluralName": "Flea Markets",
#                     "primary": true,
#                     "name": "Flea Market",
#                     "shortName": "Flea Market",
#                     "id": "4bf58dd8d48988d1f7941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/fleamarket_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Banner Carpet",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3104518836",
#                 "formattedPhone": "(310) 451-8836"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "734 Santa Monica Blvd (Lincoln)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Lincoln",
#                 "address": "734 Santa Monica Blvd",
#                 "lat": 34.01906875,
#                 "lng": -118.49145666666666
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 7,
#                 "usersCount": 7
#             },
#             "id": "4bc62b90db8fa59364e29b37",
#             "categories": [
#                 {
#                     "pluralName": "Furniture / Home Stores",
#                     "primary": true,
#                     "name": "Furniture / Home Store",
#                     "shortName": "Furniture / Home",
#                     "id": "4bf58dd8d48988d1f8941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/furniture_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Courtney's Antiques",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {
#                 "phone": "3104513333",
#                 "formattedPhone": "(310) 451-3333"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1437 Lincoln Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "1437 Lincoln Blvd",
#                 "lat": 34.01912353111931,
#                 "lng": -118.49080135034232
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 5,
#                 "usersCount": 3
#             },
#             "id": "4c4776601ddec9284b6e9d32",
#             "categories": []
#         },
#         {
#             "verified": false,
#             "name": "Mushin Hapkido",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {
#                 "phone": "3104285614",
#                 "twitter": "mushinhapkido",
#                 "formattedPhone": "(310) 428-5614"
#             },
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "717 Broadway (Lincoln)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Lincoln",
#                 "address": "717 Broadway",
#                 "lat": 34.01936768897818,
#                 "lng": -118.49173843860626
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 32,
#                 "usersCount": 5
#             },
#             "id": "4e43083d1850e8c78f43cc3c",
#             "categories": [
#                 {
#                     "pluralName": "Martial Arts Dojos",
#                     "primary": true,
#                     "name": "Martial Arts Dojo",
#                     "shortName": "Martial Arts",
#                     "id": "4bf58dd8d48988d101941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": false,
#             "name": "Physical Therapyworks",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "719 Santa Monica Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "719 Santa Monica Blvd",
#                 "lat": 34.01944,
#                 "lng": -118.491836
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 398,
#                 "usersCount": 28
#             },
#             "id": "4bd523f86798ef3b9703638d",
#             "categories": [
#                 {
#                     "pluralName": "Doctor's Offices",
#                     "primary": true,
#                     "name": "Doctor's Office",
#                     "shortName": "Doctor's Office",
#                     "id": "4bf58dd8d48988d177941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "hasMenu": true,
#             "verified": false,
#             "name": "Pizza Hut",
#             "referralId": "v-1469606406",
#             "venueChains": [
#                 {
#                     "id": "556f5631bd6a75a99036aba1"
#                 }
#             ],
#             "menu": {
#                 "url": "https://foursquare.com/v/pizza-hut/4f4357cc19834bc91f561d93/menu",
#                 "mobileUrl": "https://foursquare.com/v/4f4357cc19834bc91f561d93/device_menu",
#                 "type": "Menu",
#                 "anchor": "View Menu",
#                 "label": "Menu"
#             },
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "allowMenuUrlEdit": true,
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1411 Lincoln Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "1411 Lincoln Blvd",
#                 "lat": 34.019028,
#                 "lng": -118.490849
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 2,
#                 "usersCount": 2
#             },
#             "id": "4f4357cc19834bc91f561d93",
#             "categories": [
#                 {
#                     "pluralName": "Pizza Places",
#                     "primary": true,
#                     "name": "Pizza Place",
#                     "shortName": "Pizza",
#                     "id": "4bf58dd8d48988d1ca941735",
#                     "icon": {
#                         "prefix": "https://ss3.4sqi.net/img/categories_v2/food/pizza_",
#                         "suffix": ".png"
#                     }
#                 }
#             ]
#         },
#         {
#             "verified": true,
#             "name": "Quality Rubber Stamps",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "710 Santa Monica Blvd",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "address": "710 Santa Monica Blvd",
#                 "lat": 34.01910305354333,
#                 "lng": -118.49173651827098
#             },
#             "stats": {
#                 "tipCount": 1,
#                 "checkinsCount": 28,
#                 "usersCount": 17
#             },
#             "id": "4ca64750b7106dcb9c765ca5",
#             "categories": []
#         },
#         {
#             "verified": false,
#             "name": "Interior Illusions",
#             "referralId": "v-1469606406",
#             "venueChains": [],
#             "hereNow": {
#                 "count": 0,
#                 "groups": [],
#                 "summary": "Nobody here"
#             },
#             "specials": {
#                 "count": 0,
#                 "items": []
#             },
#             "contact": {},
#             "hasPerk": false,
#             "location": {
#                 "city": "Santa Monica",
#                 "cc": "US",
#                 "country": "United States",
#                 "postalCode": "90401",
#                 "state": "CA",
#                 "formattedAddress": [
#                     "1418 Lincoln Blvd (Santa Monica)",
#                     "Santa Monica, CA 90401",
#                     "United States"
#                 ],
#                 "crossStreet": "Santa Monica",
#                 "address": "1418 Lincoln Blvd",
#                 "lat": 34.018949,
#                 "lng": -118.490944
#             },
#             "stats": {
#                 "tipCount": 0,
#                 "checkinsCount": 14,
#                 "usersCount": 13
#             },
#             "id": "4b79deb3f964a5204d172fe3",
#             "categories": []
#         }
#     ]
# }

# %% [markdown]
# Now that we can make some sense of the structure let's practice traversing the JSON hieararchy, select one of the venues in the list and output it's name

# %%
# Solution
type(starting_list['venues'][23]['categories'][0]['name'])
# Out:
# str

# %% [markdown]
# Note that the output isn't exactly what we want. It says u'Park', and if you check the type, Python will output Unicode. This isn't good, we need to recover the original intended type. Read the following docs:
#
# https://docs.python.org/2/library/unicodedata.html, and checkup the method 'normalize'. Once you think you've understood this method. Implement it on the above call and see if you can recover the appropriate type for that data.

# %% [markdown]
# Now for some exploratory analysis, let's print the number of total venues in your list

# %%
# Solution

len(starting_list['venues'])
# Out:
# 30

# %% [markdown]
# Extract the location id for your starting list. Make sure it's normalized to its correct type, and not Unicode. Put this id in a variable called temp. From this id, we will get a list of other venues.

# %%
temp = str(starting_list['venues'][1]['id'])
print temp
# Out:
# 4c47c5d976d72d7f2a673e4d

# %%
#new tool that potentially can be used to address unicode
#unicodedata.normalize('NFD', temp).encode('ascii','ignore')

# %% [markdown]
# Print the venues list (in the nicely formatted JSON)

# %%
# Solution

temp1 = client.venues(temp);
print(json.dumps(temp1, indent = 4))
# Out:
# {
#     "venue": {
#         "reasons": {
#             "count": 1,
#             "items": [
#                 {
#                     "reasonName": "rawLikesReason",
#                     "type": "general",
#                     "summary": "Lots of people like this place"
#                 }
#             ]
#         },
#         "likes": {
#             "count": 700,
#             "groups": [
#                 {
#                     "count": 700,
#                     "items": [],
#                     "type": "others"
#                 }
#             ],
#             "summary": "700 Likes"
#         },
#         "id": "4c47c5d976d72d7f2a673e4d",
#         "createdAt": 1279772121,
#         "verified": false,
#         "venueRatingBlacklisted": true,
#         "hereNow": {
#             "count": 1,
#             "groups": [
#                 {
#                     "count": 1,
#                     "items": [],
#                     "type": "others",
#                     "name": "Other people here"
#                 }
#             ],
#             "summary": "One other person is here"
#         },
#         "shortUrl": "http://4sq.com/b5LzuF",
#         "pageUpdates": {
#             "count": 0,
#             "items": []
#         },
#         "listed": {
#             "count": 134,
#             "groups": [
#                 {
#                     "count": 134,
#                     "items": [
#                         {
#                             "description": "Our favorite places to stay, dine, and relax in this cool, boho-glam city and funky beachside town, as featured on http://www.thepurplepassport.com.",
#                             "collaborative": false,
#                             "url": "/purplepassport/list/santa-monicavenice",
#                             "photo": {
#                                 "suffix": "/9yBUAwVsH7vqFocVQ-lIFBVA-X5PD8HeNI4pZrnJX0I.jpg",
#                                 "visibility": "public",
#                                 "height": 540,
#                                 "width": 405,
#                                 "prefix": "https://irs2.4sqi.net/img/general/",
#                                 "user": {
#                                     "gender": "female",
#                                     "id": "3210747",
#                                     "firstName": "Brandy",
#                                     "photo": {
#                                         "prefix": "https://irs2.4sqi.net/img/user/",
#                                         "suffix": "/VT4QYAD2OWVMTIXB.jpg"
#                                     }
#                                 },
#                                 "id": "5016d8a1e4b07ac9f2f87a76",
#                                 "createdAt": 1343674529
#                             },
#                             "logView": true,
#                             "editable": false,
#                             "listItems": {
#                                 "count": 18,
#                                 "items": [
#                                     {
#                                         "photo": {
#                                             "suffix": "/BWjqNhkxHv4q1F6-kxjhcd-JxnO9Ei6w41-ZGFGHtdI.jpg",
#                                             "visibility": "public",
#                                             "height": 540,
#                                             "width": 720,
#                                             "prefix": "https://irs2.4sqi.net/img/general/",
#                                             "user": {
#                                                 "lastName": "Luarasi",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/16134051-GSLJWWLG3GRIO2OI.jpg"
#                                                 },
#                                                 "id": "16134051",
#                                                 "firstName": "Michel",
#                                                 "gender": "male"
#                                             },
#                                             "id": "4faf37e9e4b03338fb2e4112",
#                                             "createdAt": 1336883177
#                                         },
#                                         "id": "t501bf74ae4b03f362b832c7f",
#                                         "createdAt": 1344010068
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1344009132,
#                             "public": true,
#                             "entities": [
#                                 {
#                                     "indices": [
#                                         115,
#                                         147
#                                     ],
#                                     "object": {
#                                         "url": "http://www.thepurplepassport.com"
#                                     },
#                                     "type": "url"
#                                 }
#                             ],
#                             "followers": {
#                                 "count": 27
#                             },
#                             "user": {
#                                 "gender": "none",
#                                 "type": "page",
#                                 "id": "13420019",
#                                 "firstName": "ThePurplePassport.com",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/YXWZ3JNEL15T2ZNJ.jpg"
#                                 }
#                             },
#                             "updatedAt": 1344010549,
#                             "type": "others",
#                             "id": "501bf3ace4b07020136db023",
#                             "canonicalUrl": "https://foursquare.com/purplepassport/list/santa-monicavenice",
#                             "name": "Santa Monica/Venice"
#                         },
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/user/26912695/list/los-angeles",
#                             "photo": {
#                                 "suffix": "/U22KFOMZSFBRHO1XQ20BX1WZXL5B2OUA40TQWDRYLQOSLBP5.jpg",
#                                 "visibility": "public",
#                                 "height": 537,
#                                 "width": 720,
#                                 "prefix": "https://irs2.4sqi.net/img/general/",
#                                 "user": {
#                                     "lastName": "Nys",
#                                     "photo": {
#                                         "prefix": "https://irs2.4sqi.net/img/user/",
#                                         "suffix": "/45KE3GZPS5R3G0U3.jpg"
#                                     },
#                                     "id": "5704",
#                                     "firstName": "AD",
#                                     "gender": "male"
#                                 },
#                                 "id": "4e0cd1d0fd28246aafc3336e",
#                                 "createdAt": 1309462992
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 185,
#                                 "items": [
#                                     {
#                                         "id": "v4c47c5d976d72d7f2a673e4d",
#                                         "createdAt": 1335939191
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1335938270,
#                             "public": true,
#                             "followers": {
#                                 "count": 33
#                             },
#                             "user": {
#                                 "lastName": "Wong",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/T5D00KIIIKX42LMZ.jpg"
#                                 },
#                                 "id": "26912695",
#                                 "firstName": "Angela",
#                                 "gender": "female"
#                             },
#                             "updatedAt": 1386365026,
#                             "type": "others",
#                             "id": "4fa0ccdee4b041772323e7da",
#                             "canonicalUrl": "https://foursquare.com/user/26912695/list/los-angeles",
#                             "name": "Los Angeles"
#                         },
#                         {
#                             "description": "I had one foot out of the door, so I came up with this list for myself. Now, I'll share it with you.",
#                             "collaborative": false,
#                             "url": "/kalikross/list/before-you-leave-la-you-must",
#                             "editable": false,
#                             "listItems": {
#                                 "count": 88,
#                                 "items": [
#                                     {
#                                         "id": "v4c47c5d976d72d7f2a673e4d",
#                                         "createdAt": 1354370259
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1327184596,
#                             "public": true,
#                             "followers": {
#                                 "count": 114
#                             },
#                             "user": {
#                                 "lastName": "Kross",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/M14234S2ZSWZK0YZ.jpg"
#                                 },
#                                 "id": "9976404",
#                                 "firstName": "Kali",
#                                 "gender": "female"
#                             },
#                             "updatedAt": 1403581279,
#                             "type": "others",
#                             "id": "4f1b3ad4e4b0ce22e5544e3a",
#                             "canonicalUrl": "https://foursquare.com/kalikross/list/before-you-leave-la-you-must",
#                             "name": "Before you leave LA, you must..."
#                         },
#                         {
#                             "description": "",
#                             "collaborative": false,
#                             "url": "/averyjenkins/list/top-picks-for-favorite-cities",
#                             "photo": {
#                                 "suffix": "/2SHJPO41BTCS4UAT1NBV5DCEF3HKSPSX44ACIVLJY1UL41P5.jpg",
#                                 "visibility": "public",
#                                 "height": 612,
#                                 "width": 612,
#                                 "prefix": "https://irs2.4sqi.net/img/general/",
#                                 "user": {
#                                     "lastName": "klosowski",
#                                     "photo": {
#                                         "prefix": "https://irs3.4sqi.net/img/user/",
#                                         "suffix": "/S3OXYXONTA5OJTDN.jpg"
#                                     },
#                                     "id": "178701",
#                                     "firstName": "allen",
#                                     "gender": "male"
#                                 },
#                                 "id": "4e9a169bf5b9d590046ae36e",
#                                 "createdAt": 1318721179
#                             },
#                             "editable": false,
#                             "listItems": {
#                                 "count": 183,
#                                 "items": [
#                                     {
#                                         "id": "v4c47c5d976d72d7f2a673e4d",
#                                         "createdAt": 1329359453
#                                     }
#                                 ]
#                             },
#                             "createdAt": 1318351694,
#                             "public": true,
#                             "followers": {
#                                 "count": 56
#                             },
#                             "user": {
#                                 "lastName": "Jenkins",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/JN201OV0UUARNVZ1.jpg"
#                                 },
#                                 "id": "2242522",
#                                 "firstName": "Avery",
#                                 "gender": "male"
#                             },
#                             "updatedAt": 1468370105,
#                             "type": "others",
#                             "id": "4e94734e0aaf7d225b48216b",
#                             "canonicalUrl": "https://foursquare.com/averyjenkins/list/top-picks-for-favorite-cities",
#                             "name": "Top Picks for Favorite Cities"
#                         }
#                     ],
#                     "type": "others",
#                     "name": "Lists from other people"
#                 }
#             ]
#         },
#         "tips": {
#             "count": 87,
#             "groups": [
#                 {
#                     "count": 87,
#                     "items": [
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 8
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/51c5f2fa498e3a8ed43d0009",
#                             "photourl": "https://irs1.4sqi.net/img/general/original/7941497_lELrY4HkkMXJc5VGpP5IfkE-Jp9rzn5tSeCwbYrXNaw.jpg",
#                             "photo": {
#                                 "suffix": "/7941497_lELrY4HkkMXJc5VGpP5IfkE-Jp9rzn5tSeCwbYrXNaw.jpg",
#                                 "width": 959,
#                                 "visibility": "public",
#                                 "height": 530,
#                                 "source": {
#                                     "url": "https://foursquare.com/download/#/iphone",
#                                     "name": "Foursquare for iOS"
#                                 },
#                                 "prefix": "https://irs1.4sqi.net/img/general/",
#                                 "id": "51c5f311498e03743f3dc81f",
#                                 "createdAt": 1371927313
#                             },
#                             "agreeCount": 71,
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 72,
#                                 "groups": [
#                                     {
#                                         "count": 72,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "72 likes"
#                             },
#                             "text": "By far the most desirable part of LA to live in, Santa Monica boasts shopping, restaurants and of course ...the beach. High rent, limited space and tourists are a compromise for this prime location.",
#                             "type": "user",
#                             "id": "51c5f2fa498e3a8ed43d0009",
#                             "createdAt": 1371927290,
#                             "user": {
#                                 "lastName": "E.",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/7941497-KL1B1N2IPVUCN22R.jpg"
#                                 },
#                                 "id": "7941497",
#                                 "firstName": "Alexandra",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/5090c3ade4b08502804dbb4f",
#                             "photourl": "https://irs2.4sqi.net/img/general/original/66361_Dr7xw-JMMsDIjL4oLJqyfwm8tGZ2EccZ2PWIu2bdtk0.jpg",
#                             "photo": {
#                                 "suffix": "/66361_Dr7xw-JMMsDIjL4oLJqyfwm8tGZ2EccZ2PWIu2bdtk0.jpg",
#                                 "width": 540,
#                                 "visibility": "public",
#                                 "height": 540,
#                                 "source": {
#                                     "url": "https://foursquare.com/download/#/iphone",
#                                     "name": "Foursquare for iOS"
#                                 },
#                                 "prefix": "https://irs2.4sqi.net/img/general/",
#                                 "id": "5090c3b0e4b03b8013fd607f",
#                                 "createdAt": 1351664560
#                             },
#                             "agreeCount": 18,
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 18,
#                                 "groups": [
#                                     {
#                                         "count": 18,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "18 likes"
#                             },
#                             "text": "Santa Monica is one of the best coastal cities in LA. Enjoy a walk on the Strand on a nice day and check out the Annenberg Community Beach House which is open to the public!",
#                             "type": "user",
#                             "id": "5090c3ade4b08502804dbb4f",
#                             "createdAt": 1351664557,
#                             "user": {
#                                 "lastName": "D",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/66361_1255926239581.jpg"
#                                 },
#                                 "id": "66361",
#                                 "firstName": "Buttercup",
#                                 "gender": "none"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4d76e66241a188bfa6c992c6",
#                             "agreeCount": 10,
#                             "text": "Santa Monica is the best place ever.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 10,
#                                 "groups": [
#                                     {
#                                         "count": 10,
#                                         "items": [],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "10 likes"
#                             },
#                             "type": "user",
#                             "id": "4d76e66241a188bfa6c992c6",
#                             "createdAt": 1299637858,
#                             "user": {
#                                 "lastName": "Piatti",
#                                 "photo": {
#                                     "default": true,
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/blank_girl.png"
#                                 },
#                                 "id": "7506072",
#                                 "firstName": "Nicole",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/519c17ef498e32012a4ed616",
#                             "agreeCount": 9,
#                             "text": "I'm so happy and grateful to call Santa Monica home!  \u2764",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 9,
#                                 "groups": [
#                                     {
#                                         "count": 9,
#                                         "items": [
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Elshikh",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/VAAQRUIFKRE1C2CL.jpg"
#                                                 },
#                                                 "id": "38483694",
#                                                 "firstName": "Khaled",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Sladen",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/4797627-2SKFA5IWLWYVIHXI.jpg"
#                                                 },
#                                                 "id": "4797627",
#                                                 "firstName": "Axe",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Conroy",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/W0NGZUDCTFILA1CH.jpg"
#                                                 },
#                                                 "id": "28326158",
#                                                 "firstName": "Dylan",
#                                                 "gender": "male"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "9 likes"
#                             },
#                             "type": "user",
#                             "id": "519c17ef498e32012a4ed616",
#                             "createdAt": 1369184239,
#                             "user": {
#                                 "gender": "female",
#                                 "id": "32984131",
#                                 "firstName": "Athene",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/PO2DLKR1ZKJ4D10G.jpg"
#                                 }
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4ffa65d8e4b0d27dd90781c1",
#                             "agreeCount": 9,
#                             "text": "The Best City to Live & Work In, Hands Down!!! <3",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 9,
#                                 "groups": [
#                                     {
#                                         "count": 9,
#                                         "items": [
#                                             {
#                                                 "lastName": "Mcgee",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/142270887-LKE3NGK20ZUO5KU3.jpg"
#                                                 },
#                                                 "id": "142270887",
#                                                 "firstName": "Shantrice",
#                                                 "gender": "female"
#                                             },
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Tuncer",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/1HVE2S0MV5Q0S5NC.jpg"
#                                                 },
#                                                 "id": "25399785",
#                                                 "firstName": "Beril",
#                                                 "gender": "female"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "9 likes"
#                             },
#                             "type": "user",
#                             "id": "4ffa65d8e4b0d27dd90781c1",
#                             "createdAt": 1341810136,
#                             "user": {
#                                 "lastName": "K",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/WGAGDCED423KEIHM.jpg"
#                                 },
#                                 "id": "8934596",
#                                 "firstName": "Joseph",
#                                 "gender": "male"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4e6befe752b1456286233c2d",
#                             "agreeCount": 8,
#                             "text": "Best city to live in, ever!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 9,
#                                 "groups": [
#                                     {
#                                         "count": 9,
#                                         "items": [
#                                             {
#                                                 "lastName": "Cappelli",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/2602176-IXTUPFBPOZ3FYLZD.jpg"
#                                                 },
#                                                 "id": "2602176",
#                                                 "firstName": "Athonia",
#                                                 "gender": "female"
#                                             },
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "GB",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/328704-WJWQTEJKLIMO14OT.jpg"
#                                                 },
#                                                 "id": "328704",
#                                                 "firstName": "Carmen",
#                                                 "gender": "female"
#                                             },
#                                             {
#                                                 "lastName": "J.",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/1289597-CEKYL0SMSYI2U0KG.jpg"
#                                                 },
#                                                 "id": "1289597",
#                                                 "firstName": "Willie\ud83c\udf4a",
#                                                 "gender": "male"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "9 likes"
#                             },
#                             "type": "user",
#                             "id": "4e6befe752b1456286233c2d",
#                             "createdAt": 1315696615,
#                             "user": {
#                                 "gender": "female",
#                                 "id": "584700",
#                                 "firstName": "Yeyen",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/LYLWL4NK4PSAZIET.jpg"
#                                 }
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 1
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/501bf74ae4b03f362b832c7f",
#                             "agreeCount": 7,
#                             "url": "http://www.thepurplepassport.com/picks/los-angeles/Sight/santa-monica/",
#                             "text": "It\u2019s a cute little city that ticks all the right boxes: great food, shopping, beaches, entertainment, and culture\u2026and all of it infused with quintessential California cool.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 8,
#                                 "groups": [
#                                     {
#                                         "count": 8,
#                                         "items": [
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Pricr",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/LI4VHH2VPMLAZMZV.jpg"
#                                                 },
#                                                 "id": "67951822",
#                                                 "firstName": "Laura",
#                                                 "gender": "female"
#                                             },
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "gender": "female",
#                                                 "id": "17714215",
#                                                 "firstName": "Bubsy",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/17714215-P3BMR1HWBWUNFUV3.jpg"
#                                                 }
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "8 likes"
#                             },
#                             "type": "user",
#                             "id": "501bf74ae4b03f362b832c7f",
#                             "createdAt": 1344010058,
#                             "user": {
#                                 "gender": "none",
#                                 "type": "page",
#                                 "id": "13420019",
#                                 "firstName": "ThePurplePassport.com",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/YXWZ3JNEL15T2ZNJ.jpg"
#                                 }
#                             }
#                         },
#                         {
#                             "lang": "pt",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/504ac608e4b0f7c8ce5a6e04",
#                             "photourl": "https://irs0.4sqi.net/img/general/original/w1gq8IvZIyJyRnWUb7isjtgolltYgHzqgX5Ox7-uOYY.jpg",
#                             "photo": {
#                                 "suffix": "/w1gq8IvZIyJyRnWUb7isjtgolltYgHzqgX5Ox7-uOYY.jpg",
#                                 "width": 720,
#                                 "visibility": "public",
#                                 "height": 511,
#                                 "source": {
#                                     "url": "https://foursquare.com/download/#/iphone",
#                                     "name": "Foursquare for iOS"
#                                 },
#                                 "prefix": "https://irs0.4sqi.net/img/general/",
#                                 "id": "504ac609e4b043e9ed3f2478",
#                                 "createdAt": 1347077641
#                             },
#                             "agreeCount": 4,
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 4,
#                                 "groups": [
#                                     {
#                                         "count": 4,
#                                         "items": [
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Hall",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/ZAIMBQQ00YTR3PM3.jpg"
#                                                 },
#                                                 "id": "15309024",
#                                                 "firstName": "Tom",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Mateescu",
#                                                 "photo": {
#                                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                                     "suffix": "/ES215F4XZEHCZOX4.jpg"
#                                                 },
#                                                 "id": "5575047",
#                                                 "firstName": "Vince",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Azevedo",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/HQLQDZT0CN2LP2OK.jpg"
#                                                 },
#                                                 "id": "36814019",
#                                                 "firstName": "Nardja",
#                                                 "gender": "female"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "4 likes"
#                             },
#                             "text": "A melhor cidade da California!!!",
#                             "type": "user",
#                             "id": "504ac608e4b0f7c8ce5a6e04",
#                             "createdAt": 1347077640,
#                             "user": {
#                                 "lastName": "Azevedo",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/HQLQDZT0CN2LP2OK.jpg"
#                                 },
#                                 "id": "36814019",
#                                 "firstName": "Nardja",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4fc09dace4b089f18bb19e11",
#                             "agreeCount": 4,
#                             "text": "<3 SaMo <3 Best City I EVER Lived In!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 4,
#                                 "groups": [
#                                     {
#                                         "count": 4,
#                                         "items": [
#                                             {
#                                                 "lastName": "K",
#                                                 "photo": {
#                                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                                     "suffix": "/90937587-XHLUIQDEG4DLQNC4.jpg"
#                                                 },
#                                                 "id": "90937587",
#                                                 "firstName": "Joseph",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Hall",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/ZAIMBQQ00YTR3PM3.jpg"
#                                                 },
#                                                 "id": "15309024",
#                                                 "firstName": "Tom",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Santa Monica",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/OCL44SILHT5IU2II.png"
#                                                 },
#                                                 "id": "39636046",
#                                                 "firstName": "Taxi310",
#                                                 "gender": "none"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "4 likes"
#                             },
#                             "type": "user",
#                             "id": "4fc09dace4b089f18bb19e11",
#                             "createdAt": 1338023340,
#                             "user": {
#                                 "lastName": "K",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/WGAGDCED423KEIHM.jpg"
#                                 },
#                                 "id": "8934596",
#                                 "firstName": "Joseph",
#                                 "gender": "male"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4e3b05321850d7b505e4e025",
#                             "agreeCount": 4,
#                             "text": "You can always find a great spot to meditate in the morning!",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 4,
#                                 "groups": [
# ...
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/ZAIMBQQ00YTR3PM3.jpg"
#                                                 },
#                                                 "id": "15309024",
#                                                 "firstName": "Tom",
#                                                 "gender": "male"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "2 likes"
#                             },
#                             "type": "user",
#                             "id": "5054aae5e4b021c8a7e74bf7",
#                             "createdAt": 1347726053,
#                             "user": {
#                                 "lastName": "Rice",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/R0BZX5O4S4RJNCKY.jpg"
#                                 },
#                                 "id": "8687477",
#                                 "firstName": "Keilyn",
#                                 "gender": "female"
#                             }
#                         },
#                         {
#                             "lang": "en",
#                             "todo": {
#                                 "count": 0
#                             },
#                             "canonicalUrl": "https://foursquare.com/item/4f8078c1e4b0c2f76576c02f",
#                             "agreeCount": 2,
#                             "text": "Be aware of the traffic, always a mess. Too many lights, too many cars. Rather take Arizona, Colorado, than Santa Monica Blvd or Wilshire.",
#                             "logView": true,
#                             "disagreeCount": 0,
#                             "likes": {
#                                 "count": 2,
#                                 "groups": [
#                                     {
#                                         "count": 2,
#                                         "items": [
#                                             {
#                                                 "lastName": "Ramos",
#                                                 "photo": {
#                                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                                     "suffix": "/OIZGY0M2N2YVM4Y2.jpg"
#                                                 },
#                                                 "id": "7947291",
#                                                 "firstName": "Robert",
#                                                 "gender": "male"
#                                             },
#                                             {
#                                                 "lastName": "Hall",
#                                                 "photo": {
#                                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                                     "suffix": "/ZAIMBQQ00YTR3PM3.jpg"
#                                                 },
#                                                 "id": "15309024",
#                                                 "firstName": "Tom",
#                                                 "gender": "male"
#                                             }
#                                         ],
#                                         "type": "others"
#                                     }
#                                 ],
#                                 "summary": "2 likes"
#                             },
#                             "type": "user",
#                             "id": "4f8078c1e4b0c2f76576c02f",
#                             "createdAt": 1333819585,
#                             "user": {
#                                 "lastName": "Mex\u00eda",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/-SRN4S0PTV15PBLVU.jpg"
#                                 },
#                                 "id": "24871466",
#                                 "firstName": "Fernando",
#                                 "gender": "male"
#                             }
#                         }
#                     ],
#                     "type": "others",
#                     "name": "All tips"
#                 }
#             ]
#         },
#         "bestPhoto": {
#             "suffix": "/6129466_ne5CoLpbkQHqlEYMCZgeWQpE_KQBqD56uBHcUkuU-jk.jpg",
#             "width": 720,
#             "visibility": "public",
#             "height": 540,
#             "source": {
#                 "url": "https://foursquare.com/download/#/iphone",
#                 "name": "Foursquare for iOS"
#             },
#             "prefix": "https://irs1.4sqi.net/img/general/",
#             "id": "518530c3498ebfa54260e120",
#             "createdAt": 1367683267
#         },
#         "location": {
#             "cc": "US",
#             "country": "United States",
#             "postalCode": "90401",
#             "state": "California",
#             "formattedAddress": [
#                 "CA 90401",
#                 "United States"
#             ],
#             "lat": 34.0182338774957,
#             "lng": -118.4896945953369
#         },
#         "canonicalUrl": "https://foursquare.com/v/city-of-santa-monica/4c47c5d976d72d7f2a673e4d",
#         "tags": [
#             "beach",
#             "sm"
#         ],
#         "photos": {
#             "count": 3437,
#             "groups": [
#                 {
#                     "count": 3437,
#                     "items": [
#                         {
#                             "suffix": "/6129466_ne5CoLpbkQHqlEYMCZgeWQpE_KQBqD56uBHcUkuU-jk.jpg",
#                             "width": 720,
#                             "visibility": "public",
#                             "height": 540,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Coromina",
#                                 "photo": {
#                                     "prefix": "https://irs1.4sqi.net/img/user/",
#                                     "suffix": "/QRBZKBPKA3OWD5Q1.jpg"
#                                 },
#                                 "id": "6129466",
#                                 "firstName": "Dunia",
#                                 "gender": "female"
#                             },
#                             "id": "518530c3498ebfa54260e120",
#                             "createdAt": 1367683267
#                         },
#                         {
#                             "suffix": "/17669303_m5qD1TQ2USJyynZijoazrr52VFpRv0hSBuhNLcPkJSs.jpg",
#                             "width": 612,
#                             "visibility": "public",
#                             "height": 612,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs0.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Tyurina",
#                                 "photo": {
#                                     "prefix": "https://irs3.4sqi.net/img/user/",
#                                     "suffix": "/AFOSWDCOBYD0LHCL.jpg"
#                                 },
#                                 "id": "17669303",
#                                 "firstName": "Karina",
#                                 "gender": "female"
#                             },
#                             "id": "51ff3e98498ed0b6bccd12e2",
#                             "createdAt": 1375682200
#                         },
#                         {
#                             "suffix": "/8RMnMDXDWS9hPUsltdA1oqiFEjar1ABmQrfNU9HmOGQ.jpg",
#                             "width": 612,
#                             "visibility": "public",
#                             "height": 612,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs3.4sqi.net/img/general/",
#                             "user": {
#                                 "gender": "male",
#                                 "id": "562567",
#                                 "firstName": "Ryan",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/WF3OO4LCHDVOTZRS.jpg"
#                                 }
#                             },
#                             "id": "4f96e623e4b042e856d0c95e",
#                             "createdAt": 1335289379
#                         },
#                         {
#                             "suffix": "/1130242_tO7OvaqDDJntvW7ELhDa2fLoj6hVnGzjzlPxoOJz7Mc.jpg",
#                             "width": 1080,
#                             "visibility": "public",
#                             "height": 990,
#                             "source": {
#                                 "url": "http://instagram.com",
#                                 "name": "Instagram"
#                             },
#                             "prefix": "https://irs1.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Lee",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/A20XYJXDMU00EWBO.jpg"
#                                 },
#                                 "id": "1130242",
#                                 "firstName": "James",
#                                 "gender": "male"
#                             },
#                             "id": "56ba9733498e0e605b266ccf",
#                             "createdAt": 1455068979
#                         },
#                         {
#                             "suffix": "/55159489_2lPvT_hl3wBSRXWSUsCD9Vs17a5VJgFPjFyi_pBs318.jpg",
#                             "width": 1920,
#                             "visibility": "public",
#                             "height": 1440,
#                             "source": {
#                                 "url": "https://www.swarmapp.com",
#                                 "name": "Swarm for iOS"
#                             },
#                             "prefix": "https://irs2.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Sanchez",
#                                 "photo": {
#                                     "prefix": "https://irs0.4sqi.net/img/user/",
#                                     "suffix": "/VVE5DTGAWAG4QHWH.jpg"
#                                 },
#                                 "id": "55159489",
#                                 "firstName": "Jon",
#                                 "gender": "male"
#                             },
#                             "id": "570d2ecd498e308c4660d32c",
#                             "createdAt": 1460481741
#                         },
#                         {
#                             "suffix": "/65043585_ZF1fVVUJEXmN0yqaAQRDOWTpqlugtxc0ZemOaEtbkho.jpg",
#                             "width": 959,
#                             "visibility": "public",
#                             "height": 717,
#                             "source": {
#                                 "url": "https://foursquare.com/download/#/iphone",
#                                 "name": "Foursquare for iOS"
#                             },
#                             "prefix": "https://irs2.4sqi.net/img/general/",
#                             "user": {
#                                 "lastName": "Brieshit",
#                                 "photo": {
#                                     "prefix": "https://irs2.4sqi.net/img/user/",
#                                     "suffix": "/YYD3S2YTRQSJTESR.jpg"
#                                 },
#                                 "id": "65043585",
#                                 "firstName": "Genesis",
#                                 "gender": "male"
#                             },
#                             "id": "521fa57f498ef4d35ac2d865",
#                             "createdAt": 1377805695
#                         }
#                     ],
#                     "type": "venue",
#                     "name": "Venue photos"
#                 }
#             ]
#         },
#         "attributes": {
#             "groups": []
#         },
#         "stats": {
#             "tipCount": 87,
#             "checkinsCount": 47372,
#             "visitsCount": 51177,
#             "usersCount": 18592
#         },
#         "dislike": false,
#         "categories": [
#             {
#                 "pluralName": "Cities",
#                 "primary": true,
#                 "name": "City",
#                 "shortName": "City",
#                 "id": "50aa9e094b90af0d42d5de0d",
#                 "icon": {
#                     "prefix": "https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_",
#                     "suffix": ".png"
#                 }
#             }
#         ],
#         "ok": false,
#         "name": "City of Santa Monica",
#         "url": "http://www.santamonica.com",
#         "phrases": [
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 0,
#                                 17
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "Santa Monica Pier is a great place to watch a sunset and have..."
#                 },
#                 "phrase": "santa monica pier",
#                 "count": 2
#             },
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 4,
#                                 26
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "The Third Street Promenade is great and Bravo Cucina has a nice lunch."
#                 },
#                 "phrase": "third street promenade",
#                 "count": 2
#             },
#             {
#                 "sample": {
#                     "entities": [
#                         {
#                             "indices": [
#                                 4,
#                                 21
#                             ],
#                             "type": "keyPhrase"
#                         }
#                     ],
#                     "text": "The Best City to Live & Work In, Hands Down!!! <3"
#                 },
#                 "phrase": "best city to live",
#                 "count": 2
#             }
#         ],
#         "specials": {
#             "count": 0,
#             "items": []
#         },
#         "venueChains": [],
#         "contact": {},
#         "timeZone": "America/Los_Angeles",
#         "inbox": {
#             "count": 0,
#             "items": []
#         }
#     }
# }

# %% [markdown]
# Create a procedure that will only extract the comments in a list. There are a few ways you can do this, but I highly recommend you look up the map method from the base Python library: https://docs.python.org/2/tutorial/datastructures.html
#
# This is the same "map" function, that's one part of the map-reduce duo used in "Big Data" applications. So it may be helpful to get familiar with this method now if that's where you think you may want to take your career in the future.

# %%
# Solution
map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
# Out:
# ['By far the most desirable part of LA to live in, Santa Monica boasts shopping, restaurants and of course ...the beach. High rent, limited space and tourists are a compromise for this prime location.',
#  'Santa Monica is one of the best coastal cities in LA. Enjoy a walk on the Strand on a nice day and check out the Annenberg Community Beach House which is open to the public!',
#  'Santa Monica is the best place ever.',
#  u"I'm so happy and grateful to call Santa Monica home!  \u2764",
#  'The Best City to Live & Work In, Hands Down!!! <3',
#  'Best city to live in, ever!',
#  u'It\u2019s a cute little city that ticks all the right boxes: great food, shopping, beaches, entertainment, and culture\u2026and all of it infused with quintessential California cool.',
#  'A melhor cidade da California!!!',
#  '<3 SaMo <3 Best City I EVER Lived In!',
#  'You can always find a great spot to meditate in the morning!',
#  "Great workout area just south of the pier. It's on the beach and its free!",
#  "It's extremely green oriented. :) I love the recycling / compost emphasis !!",
#  'The summery sunsets here are beautiful',
#  'Home of the gods n_n',
#  'There is a mailbox on the corner of 18th and Ashland.',
#  'Best beach of Southern California...sorry diego people !',
#  'A nice place to live, breathe and enjoy the sea and surf.  A quaint city by the sea, to leave as clean and pristine as it was discoversdc',
#  'Main  street on the other side of Pico is a hidden gem.',
#  'Saturday morning farmers market on the promenade!',
#  'Be aware of the traffic, always a mess. Too many lights, too many cars. Rather take Arizona, Colorado, than Santa Monica Blvd or Wilshire.']

# %% [markdown]
# Now we're going to bring the above mini-tasks together into a nice little method, that will allow us to convert any foursquare JSON data into a nice tabular / rectangular table for further analysis. First instnatiate a pandas data frame.

# %%
venue_table = pd.DataFrame()

# %% [markdown]
# Write a procedure that will take your list of venues around a certain geography/lat/long whatever, and output a table that will have for each row, a comment associated for the venue (multiple comments will mean multiple rows, each per comment), the venue name, the tip count, the user count, and the store category. Make sure that each column is populated with appropriately typed values, i.e. names/categories should be strings, and numbers should be numerical data type.

# %% [markdown]
# > To the instructor: I usually don't have this much latitude to the student, but it was requested that I give some "open ended"/"munch on" problems. I suspect the students will spend the most time here, they will certainly get errors, and they will be frustrated. Look through the ideal solution and be prepared to step in when appropriate.
#
# **Hint**: Before you begin, think about the process. You're going to start with a loop of some kind, then think about the following:
# - How many of those do you need?
# - Think about the JSON structure, how "deep" do you need to penetrate the hierarchy to reach the data you want (this will help you think about how many loops you need for your crawler
# - How should you iteratively add on to your Pandas data frame?
# - Think of any tests you may need to put in to ensure your procedure does not cause an error (this may help you figure out how many if statements you may need, and where to place them.

# %%
# Solution - Note to instructor, the code may be slightly different, in particular the student should have written error-exception protocols to account for any 
# missing/empty values that may cause the procedure to kick-out in an error.

for v_index in range(len(starting_list['venues'])-1):

    temp = starting_list['venues'][v_index]['id']
    temp1 = client.venues(temp)
    #print v_index
    comment_list = map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
    for c_index in range(len(comment_list)-1):
        #print c_index
        comment_converter = comment_list[c_index]

        #print "test"
        if (starting_list['venues'][v_index]['categories']) != []:  
            venue_table = venue_table.append(pd.DataFrame({"name": starting_list['venues'][v_index]['name'],
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": starting_list['venues'][v_index]['categories'][0]['name'], 
                                             "comments": comment_converter}, index = [v_index + c_index]))
        else:
            venue_table = venue_table.append(pd.DataFrame({"name": starting_list['venues'][v_index]['name'],
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": "No categories", 
                                             "comments": comment_converter}, index = [v_index + c_index]))

# %%
# Unicode Version
# Solution - Note to instructor, the code may be slightly different, in particular the student should have written error-exception protocols to account for any 
# missing/empty values that may cause the procedure to kick-out in an error.

for v_index in range(len(starting_list['venues'])-1):
    temp = unicodedata.normalize('NFKD', starting_list['venues'][v_index]['id']).encode('ascii','ignore')
    temp1 = client.venues(temp)
    print v_index
    comment_list = map(lambda h: h['text'], temp1['venue']['tips']['groups'][0]['items'])
    for c_index in range(len(comment_list)-1):
        print c_index
        comment_converter = unicodedata.normalize('NFKD', comment_list[c_index]).encode('ascii','ignore')

        print "test"
        if (starting_list['venues'][v_index]['categories']) != []:  
            venue_table = venue_table.append(pd.DataFrame({"name": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['name']).encode('ascii','ignore'),
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['categories'][0]['name']).encode('ascii','ignore'), 
                                             "comments": comment_converter}, index = [v_index + c_index]))
        else:
            venue_table = venue_table.append(pd.DataFrame({"name": unicodedata.normalize('NFKD', starting_list['venues'][v_index]['name']).encode('ascii','ignore'),
                                            "tip count": starting_list['venues'][v_index]['stats']['tipCount'],
                                            "users count": starting_list['venues'][v_index]['stats']['usersCount'],
                                             "store category": "No categories", 
                                             "comments": comment_converter}, index = [v_index + c_index]))

# %% [markdown]
# Finally, output the Venue table

# %%
venue_table.drop_duplicates()
# Out:
#                                              comments  \
# 0                     Bums love it here! So will you!
# 1   Apparently this place doubles as a homeless sh...
# 2                  The most random shit happens here.
# 3         Quick service and friendly customer service
# 4                          Try the French fries!!!!!!
# 5         He who licks dog chocolate is nucking futs.
# 6            Sweetest staff & the #1 is delectable :)
# 7                           Attendants at night suck!
# 8   Terrible service. I came in and ordered a baco...
# 9     Drive thru is always really fast in the morning
# 10                  Worst drive through traffic ever.
# 1   By far the most desirable part of LA to live i...
# 2   Santa Monica is one of the best coastal cities...
# 3                Santa Monica is the best place ever.
# 4   I'm so happy and grateful to call Santa Monica...
# 5   The Best City to Live & Work In, Hands Down!!! <3
# 6                         Best city to live in, ever!
# 7   It’s a cute little city that ticks all the rig...
# 8                    A melhor cidade da California!!!
# 9               <3 SaMo <3 Best City I EVER Lived In!
# 10  You can always find a great spot to meditate i...
# 11  Great workout area just south of the pier. It'...
# 12  It's extremely green oriented. :) I love the r...
# 13             The summery sunsets here are beautiful
# 14                               Home of the gods n_n
# 15  There is a mailbox on the corner of 18th and A...
# 16  Best beach of Southern California...sorry dieg...
# 17  A nice place to live, breathe and enjoy the se...
# 18  Main  street on the other side of Pico is a hi...
# 19  Saturday morning farmers market on the promenade!
# ..                                                ...
# 18  Stumbled upon here & left w/graphic novels! Co...
# 19  Bags Unlimited has a new blog and posts new pr...
# 20  6 blocks from the beach! What more can u ask f...
# 21  Been shopping at this place ever since I was a...
# 22  I clipped the owner's car in the parking lot a...
# 23  People here are very nice and very knowledgeable.
# 24                   Only open till 7pm on Sundays...
# 25  Really love their indie selections and their g...
# 26  This place is massive compared to most shops I...
# 27  Ask for suggestions about great books to read....
# 28  Check out their comedy show... Especially if I...
# 29  The staff is so friendly, their selection make...
# 19                    You can eat on the couches now!
# 20          Happy hour prices on the patio are cheap.
# 21  Great happy hour menu. Awesome polish food. Vi...
# 22  .....and, actually I have no idea who Vinny is...
# 23  My new favorite is the Beef Stronganoff~their ...
# 24                 Get a shot of buffalo grass vodka.
# 25  The new York duck, is better than the turkey, ...
# 26  Feels like an old polish house inside, slightl...
# 27  Super cheap happy hour on the patio! Tuesday t...
# 28  Awesome homey feel to the place, and never tri...
# 29  I've never been inside this place... because I...
# 30  The chicken soup with lamb dumplings and picke...
# 31  Cool patio area in back. Decent food. Huge scr...
# 32  KCRW's Evan Kleiman & Jonathan Gold have Warsz...
# 33                      The Stuffed Cabbage is a MUST
# 35  Dried plums wrapped in bacon is where you must...
# 36  An EXCEPTIONAL place to get your Eastern Europ...
# 37        Mmmm...Tatanka's! Vinnie really IS the man!
#
#                        name               store category  tip count  \
# 0           Jack in the Box                 Burger Joint         12
# 1           Jack in the Box                 Burger Joint         12
# 2           Jack in the Box                 Burger Joint         12
# 3           Jack in the Box                 Burger Joint         12
# 4           Jack in the Box                 Burger Joint         12
# 5           Jack in the Box                 Burger Joint         12
# 6           Jack in the Box                 Burger Joint         12
# 7           Jack in the Box                 Burger Joint         12
# 8           Jack in the Box                 Burger Joint         12
# 9           Jack in the Box                 Burger Joint         12
# 10          Jack in the Box                 Burger Joint         12
# 1      City of Santa Monica                         City         87
# 2      City of Santa Monica                         City         87
# 3      City of Santa Monica                         City         87
# 4      City of Santa Monica                         City         87
# 5      City of Santa Monica                         City         87
# 6      City of Santa Monica                         City         87
# 7      City of Santa Monica                         City         87
# 8      City of Santa Monica                         City         87
# 9      City of Santa Monica                         City         87
# 10     City of Santa Monica                         City         87
# 11     City of Santa Monica                         City         87
# 12     City of Santa Monica                         City         87
# 13     City of Santa Monica                         City         87
# 14     City of Santa Monica                         City         87
# 15     City of Santa Monica                         City         87
# 16     City of Santa Monica                         City         87
# 17     City of Santa Monica                         City         87
# 18     City of Santa Monica                         City         87
# 19     City of Santa Monica                         City         87
# ..                      ...                          ...        ...
# 18  Hi De Ho Comics & Books                   Comic Shop         13
# 19  Hi De Ho Comics & Books                   Comic Shop         13
# 20  Hi De Ho Comics & Books                   Comic Shop         13
# 21  Hi De Ho Comics & Books                   Comic Shop         13
# 22  Hi De Ho Comics & Books                   Comic Shop         13
# 23  Hi De Ho Comics & Books                   Comic Shop         13
# 24  Hi De Ho Comics & Books                   Comic Shop         13
# 25  Hi De Ho Comics & Books                   Comic Shop         13
# 26  Hi De Ho Comics & Books                   Comic Shop         13
# 27  Hi De Ho Comics & Books                   Comic Shop         13
# 28  Hi De Ho Comics & Books                   Comic Shop         13
# 29  Hi De Ho Comics & Books                   Comic Shop         13
# 19                 Warszawa  Eastern European Restaurant         22
# 20                 Warszawa  Eastern European Restaurant         22
# 21                 Warszawa  Eastern European Restaurant         22
# 22                 Warszawa  Eastern European Restaurant         22
# 23                 Warszawa  Eastern European Restaurant         22
# 24                 Warszawa  Eastern European Restaurant         22
# 25                 Warszawa  Eastern European Restaurant         22
# 26                 Warszawa  Eastern European Restaurant         22
# 27                 Warszawa  Eastern European Restaurant         22
# 28                 Warszawa  Eastern European Restaurant         22
# 29                 Warszawa  Eastern European Restaurant         22
# 30                 Warszawa  Eastern European Restaurant         22
# 31                 Warszawa  Eastern European Restaurant         22
# 32                 Warszawa  Eastern European Restaurant         22
# 33                 Warszawa  Eastern European Restaurant         22
# 35                 Warszawa  Eastern European Restaurant         22
# 36                 Warszawa  Eastern European Restaurant         22
# 37                 Warszawa  Eastern European Restaurant         22
#
#     users count
# 0           879
# 1           879
# 2           879
# 3           879
# 4           879
# 5           879
# 6           879
# 7           879
# 8           879
# 9           879
# 10          879
# 1         16862
# 2         16862
# 3         16862
# 4         16862
# 5         16862
# 6         16862
# 7         16862
# 8         16862
# 9         16862
# 10        16862
# 11        16862
# 12        16862
# 13        16862
# 14        16862
# 15        16862
# 16        16862
# 17        16862
# 18        16862
# 19        16862
# ..          ...
# 18          502
# 19          502
# 20          502
# 21          502
# 22          502
# 23          502
# 24          502
# 25          502
# 26          502
# 27          502
# 28          502
# 29          502
# 19         1530
# 20         1530
# 21         1530
# 22         1530
# 23         1530
# 24         1530
# 25         1530
# 26         1530
# 27         1530
# 28         1530
# 29         1530
# 30         1530
# 31         1530
# 32         1530
# 33         1530
# 35         1530
# 36         1530
# 37         1530
#
# [135 rows x 5 columns]

# %% [markdown]
# You've done it! You've built a simple crawler that traverses a JSON directory, and you've deposited the results in a nice Pandas data frame. Congratulations! You're now ready for more data-mining in the future, and have just beefed up the **data** part of the data science combination :)
