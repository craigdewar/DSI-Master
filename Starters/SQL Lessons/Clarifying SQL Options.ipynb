# %% [markdown]
# # SQLite
# SQLite is a simple SQL option that runs on a local *file* instead of a local *server*. This makes things much easier because
# - you don't have to activate a server
# - you don't need to deal with things like users, passwords, permissions, etc.
# - It can also be saved to anything that can save data (e.g. a USB drive) and can be emailed.
# - It is typically small and efficient
# - You can store multiple datatypes in one column
#
# However,
# - it is not as powerful as PostgreSQL
# - lacks some fundamental features, such as several datatypes and commands (e.g. `RIGHT OUTER JOIN` or `FOR EACH`).
# - It also doesn't do well with big data, high volume, or multiple user environments.
#
# Check out [this website](https://www.digitalocean.com/community/tutorials/sqlite-vs-mysql-vs-postgresql-a-comparison-of-relational-database-management-systems) for more info.

# %% [markdown]
# ## How to connect to a SQLite Database
# We're going to do this with Pandas first, because if we're looking at some database we probably want to import it into Pandas eventually anyway

# %% [markdown]
# ##### Step 1: Import sqlite3 and pandas

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ##### Step 2: create a connection to the database.
# Make sure the "`Chinook_Sqlite.sqlite`" file is in the same folder as this notebook, or include the relative filepath.

# %%
conn = sqlite3.connect('Chinook_Sqlite.sqlite')

# %% [markdown]
# **NOTE: if the "`Chinook_Sqlite.sqlite`" file is not there, it will NOT throw an error, it will create a new file with that name.**

# %% [markdown]
# ##### Step 3: See what tables are in the database using pandas
# You could skip this step if you know what table you're looking for

# %%
pd.read_sql("""SELECT * FROM sqlite_master
            WHERE type = 'table';""", #notice the triple quotes allow multi-line queries
           con = conn) #notice this is where we use the "conn" connection we made above.
# Out:
#      type           name       tbl_name  rootpage  \
# 0   table          Album          Album         2
# 1   table         Artist         Artist         3
# 2   table       Customer       Customer         4
# 3   table       Employee       Employee         7
# 4   table          Genre          Genre         9
# 5   table        Invoice        Invoice        10
# 6   table    InvoiceLine    InvoiceLine        12
# 7   table      MediaType      MediaType        14
# 8   table       Playlist       Playlist        15
# 9   table  PlaylistTrack  PlaylistTrack        16
# 10  table          Track          Track        19
#
#                                                   sql
# 0   CREATE TABLE [Album]\n(\n    [AlbumId] INTEGER...
# 1   CREATE TABLE [Artist]\n(\n    [ArtistId] INTEG...
# 2   CREATE TABLE [Customer]\n(\n    [CustomerId] I...
# 3   CREATE TABLE [Employee]\n(\n    [EmployeeId] I...
# 4   CREATE TABLE [Genre]\n(\n    [GenreId] INTEGER...
# 5   CREATE TABLE [Invoice]\n(\n    [InvoiceId] INT...
# 6   CREATE TABLE [InvoiceLine]\n(\n    [InvoiceLin...
# 7   CREATE TABLE [MediaType]\n(\n    [MediaTypeId]...
# 8   CREATE TABLE [Playlist]\n(\n    [PlaylistId] I...
# 9   CREATE TABLE [PlaylistTrack]\n(\n    [Playlist...
# 10  CREATE TABLE [Track]\n(\n    [TrackId] INTEGER...

# %% [markdown]
# ##### Step 4: Create a query with pandas and save to a variable

# %%
df = pd.read_sql("""SELECT * FROM ALBUM;""", con=conn)
df.head()
# Out:
#    AlbumId                                  Title  ArtistId
# 0        1  For Those About To Rock We Salute You         1
# 1        2                      Balls to the Wall         2
# 2        3                      Restless and Wild         2
# 3        4                      Let There Be Rock         1
# 4        5                               Big Ones         3

# %% [markdown]
# # PostgreSQL
# PostgreSQL is a powerful, server-based SQL option. It can do just about anything and it's FREE because it's open-source. There's also an active community of people to help you troubleshoot. It's biggest disadvantages are that it isn't as popular as things like MySQL or Oracle, and there is can be a steep learning curve. Also, it can be over-powered for simple, read-heavy tasks so it can actually under-perform in those situations.

# %% [markdown]
# ## How to connect to a PostgreSQL Database
# We'll use sqlalchemy for this, because it interacts well with Pandas

# %% [markdown]
# ##### Step 1: Import sqlalchemy and pandas

# %%
import sqlalchemy
import pandas as pd

# %% [markdown]
# **NOTE: An alternative is to use psycopg2 instead, but this is considered a bit out-dated.**

# %% [markdown]
# ##### Step 2: create a connection (called "engine" in sqlalchemy) to the database.
# The connection string follows the form:
# `postgresql://"user":"password"@"host":"port"/"database"`

# %%
# We'll connect to the Nortwinds Database, which has the following parameters:
# User: dsi_student
# Password: gastudents
# Host: dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com
# Port: 5432
# Database: northwind
engine = sqlalchemy.create_engine("postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com:5432/northwind")

# %% [markdown]
# **NOTE: If you were using psycopg2, you'd use the syntax: `psycopg2.connect("SAME STRING AS ABOVE")`**
#
# OR
#
# **`psycopg2.connect(user='dsi_student', password='gastudents', host='dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com', port='5432', database='northwind')`**

# %% [markdown]
# ##### Step 3: See what tables are in the database using pandas
# You could skip this step if you know what table you're looking for

# %%
pd.read_sql("""SELECT * FROM information_schema.tables
            WHERE table_schema = 'public';""",
           con = engine) #notice this is where we use the "engine" connection we made above.
# Out:
#    table_catalog table_schema            table_name  table_type  \
# 0      northwind       public            categories  BASE TABLE
# 1      northwind       public     full_order_table5  BASE TABLE
# 2      northwind       public                    fo  BASE TABLE
# 3      northwind       public            table_join  BASE TABLE
# 4      northwind       public            full_order  BASE TABLE
# 5      northwind       public  customercustomerdemo  BASE TABLE
# 6      northwind       public  customerdemographics  BASE TABLE
# 7      northwind       public             customers  BASE TABLE
# 8      northwind       public             employees  BASE TABLE
# 9      northwind       public   employeeterritories  BASE TABLE
# 10     northwind       public         order_details  BASE TABLE
# 11     northwind       public                orders  BASE TABLE
# 12     northwind       public              products  BASE TABLE
# 13     northwind       public                region  BASE TABLE
# 14     northwind       public              shippers  BASE TABLE
# 15     northwind       public          shippers_tmp  BASE TABLE
# 16     northwind       public             suppliers  BASE TABLE
# 17     northwind       public           territories  BASE TABLE
# 18     northwind       public              usstates  BASE TABLE
# 19     northwind       public                table1  BASE TABLE
# 20     northwind       public                movies  BASE TABLE
# 21     northwind       public               ratings  BASE TABLE
# 22     northwind       public      categoriesmerged  BASE TABLE
# 23     northwind       public           order_table  BASE TABLE
# 24     northwind       public              full_ord  BASE TABLE
# 25     northwind       public             new_table  BASE TABLE
# 26     northwind       public      full_order_table  BASE TABLE
# 27     northwind       public     full_order_table2  BASE TABLE
# 28     northwind       public     full_order_table3  BASE TABLE
# 29     northwind       public     full_order_table4  BASE TABLE
# 30     northwind       public            temp_table  BASE TABLE
# 31     northwind       public          full_orders_  BASE TABLE
# 32     northwind       public           fullorders_  BASE TABLE
# 33     northwind       public          fullorders__  BASE TABLE
# 34     northwind       public            fullorders  BASE TABLE
# 35     northwind       public          descriptions  BASE TABLE
# 36     northwind       public                 price  BASE TABLE
# 37     northwind       public         descriptions1  BASE TABLE
# 38     northwind       public              empterid  BASE TABLE
# 39     northwind       public            google_app  BASE TABLE
# 40     northwind       public                 final  BASE TABLE
# 41     northwind       public                final2  BASE TABLE
# 42     northwind       public                final3  BASE TABLE
# 43     northwind       public                final4  BASE TABLE
# 44     northwind       public   credit_card_feature  BASE TABLE
# 45     northwind       public                price2  BASE TABLE
# 46     northwind       public         descriptions2  BASE TABLE
# 47     northwind       public             empterid2  BASE TABLE
# 48     northwind       public                final5  BASE TABLE
# 49     northwind       public              my_table  BASE TABLE
# 50     northwind       public             newregion  BASE TABLE
# 51     northwind       public          updatdregion  BASE TABLE
# 52     northwind       public         updatedregion  BASE TABLE
# 53     northwind       public        updatedregion1  BASE TABLE
# 54     northwind       public          ship_secrets        VIEW
# 55     northwind       public                 top_5        VIEW
# 56     northwind       public              sessions  BASE TABLE
#
#    self_referencing_column_name reference_generation  \
# 0                          None                 None
# 1                          None                 None
# 2                          None                 None
# 3                          None                 None
# 4                          None                 None
# 5                          None                 None
# 6                          None                 None
# 7                          None                 None
# 8                          None                 None
# 9                          None                 None
# 10                         None                 None
# 11                         None                 None
# 12                         None                 None
# 13                         None                 None
# 14                         None                 None
# 15                         None                 None
# 16                         None                 None
# 17                         None                 None
# 18                         None                 None
# 19                         None                 None
# 20                         None                 None
# 21                         None                 None
# 22                         None                 None
# 23                         None                 None
# 24                         None                 None
# 25                         None                 None
# 26                         None                 None
# 27                         None                 None
# 28                         None                 None
# 29                         None                 None
# 30                         None                 None
# 31                         None                 None
# 32                         None                 None
# 33                         None                 None
# 34                         None                 None
# 35                         None                 None
# 36                         None                 None
# 37                         None                 None
# 38                         None                 None
# 39                         None                 None
# 40                         None                 None
# 41                         None                 None
# 42                         None                 None
# 43                         None                 None
# 44                         None                 None
# 45                         None                 None
# 46                         None                 None
# 47                         None                 None
# 48                         None                 None
# 49                         None                 None
# 50                         None                 None
# 51                         None                 None
# 52                         None                 None
# 53                         None                 None
# 54                         None                 None
# 55                         None                 None
# 56                         None                 None
#
#    user_defined_type_catalog user_defined_type_schema user_defined_type_name  \
# 0                       None                     None                   None
# 1                       None                     None                   None
# 2                       None                     None                   None
# 3                       None                     None                   None
# 4                       None                     None                   None
# 5                       None                     None                   None
# 6                       None                     None                   None
# 7                       None                     None                   None
# 8                       None                     None                   None
# 9                       None                     None                   None
# 10                      None                     None                   None
# 11                      None                     None                   None
# 12                      None                     None                   None
# 13                      None                     None                   None
# 14                      None                     None                   None
# 15                      None                     None                   None
# 16                      None                     None                   None
# 17                      None                     None                   None
# 18                      None                     None                   None
# 19                      None                     None                   None
# 20                      None                     None                   None
# 21                      None                     None                   None
# 22                      None                     None                   None
# 23                      None                     None                   None
# 24                      None                     None                   None
# 25                      None                     None                   None
# 26                      None                     None                   None
# 27                      None                     None                   None
# 28                      None                     None                   None
# 29                      None                     None                   None
# 30                      None                     None                   None
# 31                      None                     None                   None
# 32                      None                     None                   None
# 33                      None                     None                   None
# 34                      None                     None                   None
# 35                      None                     None                   None
# 36                      None                     None                   None
# 37                      None                     None                   None
# 38                      None                     None                   None
# 39                      None                     None                   None
# 40                      None                     None                   None
# 41                      None                     None                   None
# 42                      None                     None                   None
# 43                      None                     None                   None
# 44                      None                     None                   None
# 45                      None                     None                   None
# 46                      None                     None                   None
# 47                      None                     None                   None
# 48                      None                     None                   None
# 49                      None                     None                   None
# 50                      None                     None                   None
# 51                      None                     None                   None
# 52                      None                     None                   None
# 53                      None                     None                   None
# 54                      None                     None                   None
# 55                      None                     None                   None
# 56                      None                     None                   None
#
#    is_insertable_into is_typed commit_action
# 0                 YES       NO          None
# 1                 YES       NO          None
# 2                 YES       NO          None
# 3                 YES       NO          None
# 4                 YES       NO          None
# 5                 YES       NO          None
# 6                 YES       NO          None
# 7                 YES       NO          None
# 8                 YES       NO          None
# 9                 YES       NO          None
# 10                YES       NO          None
# 11                YES       NO          None
# 12                YES       NO          None
# 13                YES       NO          None
# 14                YES       NO          None
# 15                YES       NO          None
# 16                YES       NO          None
# 17                YES       NO          None
# 18                YES       NO          None
# 19                YES       NO          None
# 20                YES       NO          None
# 21                YES       NO          None
# 22                YES       NO          None
# 23                YES       NO          None
# 24                YES       NO          None
# 25                YES       NO          None
# 26                YES       NO          None
# 27                YES       NO          None
# 28                YES       NO          None
# 29                YES       NO          None
# 30                YES       NO          None
# 31                YES       NO          None
# 32                YES       NO          None
# 33                YES       NO          None
# 34                YES       NO          None
# 35                YES       NO          None
# 36                YES       NO          None
# 37                YES       NO          None
# 38                YES       NO          None
# 39                YES       NO          None
# 40                YES       NO          None
# 41                YES       NO          None
# 42                YES       NO          None
# 43                YES       NO          None
# 44                YES       NO          None
# 45                YES       NO          None
# 46                YES       NO          None
# 47                YES       NO          None
# 48                YES       NO          None
# 49                YES       NO          None
# 50                YES       NO          None
# 51                YES       NO          None
# 52                YES       NO          None
# 53                YES       NO          None
# 54                YES       NO          None
# 55                 NO       NO          None
# 56                YES       NO          None

# %% [markdown]
# ##### Step 4: Create a query with pandas and save to a variable

# %%
df = pd.read_sql("""SELECT * FROM usstates;""", con=engine)
df.head()
# Out:
#    StateID   StateName StateAbbr StateRegion
# 0        1     Alabama        AL       south
# 1        2      Alaska        AK       north
# 2        3     Arizona        AZ        west
# 3        4    Arkansas        AR       south
# 4        5  California        CA        west

# %% [markdown]
# ##### Note: you can create a table using `pd.read_sql()`, but it will give you an error, even when it works...

# %% [markdown]
# # SQL Magic Alternative
# SQL Magic is nice because it doesn't require strings or specifying the connection each time. It's also useful for creating and writing to tables, which you will especially see in the next lesson.

# %% [markdown]
# ##### Step 1: Load the SQL extension

# %%
# %load_ext sql

# %% [markdown]
# ##### Step 2:  Connect to a database
# Use the exact same connection string as we used above with the sqlalchemy connection.

# %%
# %sql postgresql://dsi_student:gastudents@dsi.c20gkj5cvu3l.us-east-1.rds.amazonaws.com:5432/northwind
# Out:
# u'Connected: dsi_student@northwind'

# %% [markdown]
# **NOTE: to connect to the sqlite database we used above, use this:**
#
# `%sql sqlite:///Chinook_Sqlite.sqlite` (notice the three slashes)

# %% [markdown]
# ##### Step 3: Test out a query
# Note: a single `"%"` is LINE magic, and a double `"%%"` is CELL magic. CELL magic works on multiple lines, LINE magic works on a singe line

# %%
# %%sql
# SELECT * FROM usstates
# WHERE "StateRegion" = 'south'
# Out:
# 9 rows affected.
# [(1, u'Alabama', u'AL', u'south'),
#  (4, u'Arkansas', u'AR', u'south'),
#  (10, u'Florida', u'FL', u'south'),
#  (11, u'Georgia', u'GA', u'south'),
#  (18, u'Kentucky', u'KY', u'south'),
#  (19, u'Louisiana', u'LA', u'south'),
#  (25, u'Mississippi', u'MS', u'south'),
#  (26, u'Missouri', u'MO', u'south'),
#  (49, u'West Virginia', u'WV', u'south')]

# %% [markdown]
# ##### Step 4: Save the result of a query
# NOTE: You must use LINE magic, not CELL magic, so you'll need to put a space and a backslash at the end of a line to continue onto a new one

# %%
result = %sql SELECT * FROM usstates \
WHERE "StateRegion" = 'south'
# Out:
# 9 rows affected.

# %%
# Notice: "result" is a unique datatype, not a dataframe yet
type(result)
# Out:
# sql.run.ResultSet

# %% [markdown]
# ##### Step 5: Make it into a dataframe and save as a variable

# %%
df = result.DataFrame()
df.head()
# Out:
#    StateID StateName StateAbbr StateRegion
# 0        1   Alabama        AL       south
# 1        4  Arkansas        AR       south
# 2       10   Florida        FL       south
# 3       11   Georgia        GA       south
# 4       18  Kentucky        KY       south
